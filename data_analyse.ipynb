# %%
#import json
import pandas as pd

# %%
psycho_path = 'data/Q_R_Psycho.csv'
psycho_list = pd.read_csv(psycho_path,sep=';',names=['Question','Reponse'])
psycho_frame = pd.DataFrame(psycho_list,columns=['Question','Reponse'])

# %%
# data analyse
psycho_frame.sample(5)
# Out:
#                                              Question  \
# 16  Comment réagir face à une personne qui a des d...
# 18  Quelles sont les associations d'aide aux famil...
# 4   Qu'est-ce que je pourrais faire quand ma compa...
# 39  Comment aider une personne qui souffre d'agora...
# 28  J'aimerai connaitre une définition précis des ...
#
#                                               Reponse
# 16  Résidez-vous dans une grande ville ou non loin...
# 18  Certains choix sont très difficiles et doulour...
# 4   votre épouse a été claire d'après ce que vous ...
# 39  L'agoraphobie est très handicapante car elle e...
# 28  Les troubles cognitifs c'est tout simplement l...

# %%
psycho_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
# Question    40 non-null object
# Reponse     40 non-null object
# dtypes: object(2)
# memory usage: 720.0+ bytes

# %%
psycho_frame.Question.apply(lambda x: len(str(x))).value_counts().plot(kind='pie')

# %%
psycho_frame.Reponse.apply(lambda x: len(str(x))).value_counts().plot(kind='pie')

# %%
psycho_frame.Question.apply(lambda x:len(str(x))).describe()
# Out:
# count    40.00000
# mean     54.97500
# std      16.48385
# min      27.00000
# 25%      40.00000
# 50%      51.50000
# 75%      65.50000
# max      94.00000
# Name: Question, dtype: float64

# %%
psycho_frame.Reponse.apply(lambda x:len(str(x))).describe()
# Out:
# count      40.000000
# mean      537.775000
# std       328.356786
# min        85.000000
# 25%       323.750000
# 50%       480.000000
# 75%       636.500000
# max      1526.000000
# Name: Reponse, dtype: float64

# %%
psycho_frame.Question.apply(lambda x: len(str(x))).plot(kind='hist')

# %%
psycho_frame.Reponse.apply(lambda x: len(str(x))).plot(kind='hist')

# %%
psycho_frame.Question.apply(lambda x: len(str(x))).plot(kind='box')

# %%
psycho_frame.Reponse.apply(lambda x: len(str(x))).plot(kind='box')
